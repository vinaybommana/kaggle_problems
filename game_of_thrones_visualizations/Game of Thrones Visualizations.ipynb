# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
df = pd.read_csv("battles.csv")

# %%
df.head()
# df.columns
# df.dtypes
# Out:
#                             name  year  battle_number  \
# 0     Battle of the Golden Tooth   298              1
# 1    Battle at the Mummer's Ford   298              2
# 2             Battle of Riverrun   298              3
# 3       Battle of the Green Fork   298              4
# 4  Battle of the Whispering Wood   298              5
#
#               attacker_king             defender_king attacker_1 attacker_2  \
# 0  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 1  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 2  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 3                Robb Stark  Joffrey/Tommen Baratheon      Stark        NaN
# 4                Robb Stark  Joffrey/Tommen Baratheon      Stark      Tully
#
#   attacker_3 attacker_4 defender_1 ...  major_death  major_capture  \
# 0        NaN        NaN      Tully ...          1.0            0.0
# 1        NaN        NaN  Baratheon ...          1.0            0.0
# 2        NaN        NaN      Tully ...          0.0            1.0
# 3        NaN        NaN  Lannister ...          1.0            1.0
# 4        NaN        NaN  Lannister ...          1.0            1.0
#
#    attacker_size defender_size  \
# 0        15000.0        4000.0
# 1            NaN         120.0
# 2        15000.0       10000.0
# 3        18000.0       20000.0
# 4         1875.0        6000.0
#
#                                   attacker_commander  \
# 0                                    Jaime Lannister
# 1                                     Gregor Clegane
# 2                       Jaime Lannister, Andros Brax
# 3  Roose Bolton, Wylis Manderly, Medger Cerwyn, H...
# 4                          Robb Stark, Brynden Tully
#
#                                   defender_commander  summer         location  \
# 0                               Clement Piper, Vance     1.0     Golden Tooth
# 1                                   Beric Dondarrion     1.0    Mummer's Ford
# 2                      Edmure Tully, Tytos Blackwood     1.0         Riverrun
# 3  Tywin Lannister, Gregor Clegane, Kevan Lannist...     1.0       Green Fork
# 4                                    Jaime Lannister     1.0  Whispering Wood
#
#             region note
# 0  The Westerlands  NaN
# 1   The Riverlands  NaN
# 2   The Riverlands  NaN
# 3   The Riverlands  NaN
# 4   The Riverlands  NaN
#
# [5 rows x 25 columns]

# %%
sns.set_style("whitegrid")
# gives the grid "whitegrid"

example_one = sns.barplot(x="year", y="major_death", data=df)

# %%
example_two = sns.factorplot(x="attacker_size", y="defender_size", hue="attacker_outcome", data=df, size=6, kind="bar", palette="muted")

# %%
example_two = sns.factorplot(x="attacker_size", y="defender_size", hue="attacker_outcome", data=df, size=6, kind="bar", palette="muted")

plt.xticks(rotation=70)
plt.rcParams["xtick.labelsize"] = 9

# %% [markdown]
# ### Joint Kernel Estimate

# %%
sns.set(style="white")

random_state = np.random.RandomState(10)
mean = [2, 2]
cov = [(1, .5), (.5, 1)]

x1, x2 = np.random.multivariate_normal(mean, cov, 500).T
x1 = pd.Series(x1, name="Example_x")
x2 = pd.Series(x2, name="Example_Y")

example_three = sns.jointplot(x1, x2, kind="kde", size=7, space=0)

# %% [markdown]
# ## Univariate distributions

# %%
import matplotlib as mpl

# %%
sns.set(style="whitegrid")
attacker_sizes = df.attacker_size
attacker_sizes.dropna(inplace=True)
attacker_sizes.head()

# defender sizes
defender_sizes = df.defender_size
defender_sizes.dropna(inplace=True)
defender_sizes.head()
sns.distplot(attacker_sizes)
sns.distplot(defender_sizes)
# Out:
# c:\users\vinay.bommana\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "
# c:\users\vinay.bommana\appdata\local\programs\python\python36-32\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
character_deaths = pd.read_csv("character-deaths.csv")
character_deaths.head()
character_deaths['Book of Death'].fillna(0, inplace=True)
character_deaths['Book of Death'].describe()
death_count_books = {key: 0 for key in range(0, 6)}

for item in character_deaths['Book of Death']:
    death_count_books[int(item)] += 1
# print(death_count_books)
death_count = pd.DataFrame({'Book': list(death_count_books.keys()), 'Deaths': list(death_count_books.values())})
# death_count.head()

sns.barplot(x=death_count.Book, y=death_count.Deaths)

# %%
set(df.region)
len(set(df.region))
# Out:
# {'Beyond the Wall',
#  'The Crownlands',
#  'The North',
#  'The Reach',
#  'The Riverlands',
#  'The Stormlands',
#  'The Westerlands'}

# %%
df[['name', 'attacker_king', 'defender_king', 'region', 'attacker_outcome']].dropna()
# Out:
#                                                  name  \
# 0                          Battle of the Golden Tooth
# 1                         Battle at the Mummer's Ford
# 2                                  Battle of Riverrun
# 3                            Battle of the Green Fork
# 4                       Battle of the Whispering Wood
# 5                                 Battle of the Camps
# 6                                       Sack of Darry
# 7                               Battle of Moat Cailin
# 8                            Battle of Deepwood Motte
# 9                           Battle of the Stony Shore
# 10                         Battle of Torrhen's Square
# 11                               Battle of Winterfell
# 12                           Sack of Torrhen's Square
# 13                                 Sack of Winterfell
# 14                                  Battle of Oxcross
# 15                               Siege of Storm's End
# 16                                Battle of the Fords
# 17                                  Sack of Harrenhal
# 18                                 Battle of the Crag
# 19                           Battle of the Blackwater
# 20                                     Siege of Darry
# 21                               Battle of Duskendale
# 23                            Battle of the Ruby Ford
# 25                                    The Red Wedding
# 26                                   Siege of Seagard
# 27                             Battle of Castle Black
# 28                                Fall of Moat Cailin
# 30                         Retaking of Deepwood Motte
# 31                       Battle of the Shield Islands
# 32  Invasion of Ryamsport, Vinetown, and Starfish ...
# 33                        Second Seige of Storm's End
# 34                               Siege of Dragonstone
# 35                                  Siege of Riverrun
# 36                                 Siege of Raventree
#
#                attacker_king             defender_king           region  \
# 0   Joffrey/Tommen Baratheon                Robb Stark  The Westerlands
# 1   Joffrey/Tommen Baratheon                Robb Stark   The Riverlands
# 2   Joffrey/Tommen Baratheon                Robb Stark   The Riverlands
# 3                 Robb Stark  Joffrey/Tommen Baratheon   The Riverlands
# 4                 Robb Stark  Joffrey/Tommen Baratheon   The Riverlands
# 5                 Robb Stark  Joffrey/Tommen Baratheon   The Riverlands
# 6   Joffrey/Tommen Baratheon                Robb Stark   The Riverlands
# 7        Balon/Euron Greyjoy                Robb Stark        The North
# 8        Balon/Euron Greyjoy                Robb Stark        The North
# 9        Balon/Euron Greyjoy                Robb Stark        The North
# 10                Robb Stark       Balon/Euron Greyjoy        The North
# 11       Balon/Euron Greyjoy                Robb Stark        The North
# 12       Balon/Euron Greyjoy       Balon/Euron Greyjoy        The North
# 13  Joffrey/Tommen Baratheon                Robb Stark        The North
# 14                Robb Stark  Joffrey/Tommen Baratheon  The Westerlands
# 15         Stannis Baratheon           Renly Baratheon   The Stormlands
# 16  Joffrey/Tommen Baratheon                Robb Stark   The Riverlands
# 17                Robb Stark  Joffrey/Tommen Baratheon   The Riverlands
# 18                Robb Stark  Joffrey/Tommen Baratheon  The Westerlands
# 19         Stannis Baratheon  Joffrey/Tommen Baratheon   The Crownlands
# 20                Robb Stark  Joffrey/Tommen Baratheon   The Riverlands
# 21                Robb Stark  Joffrey/Tommen Baratheon   The Crownlands
# 23  Joffrey/Tommen Baratheon                Robb Stark   The Riverlands
# 25  Joffrey/Tommen Baratheon                Robb Stark   The Riverlands
# 26                Robb Stark  Joffrey/Tommen Baratheon   The Riverlands
# 27         Stannis Baratheon              Mance Rayder  Beyond the Wall
# 28  Joffrey/Tommen Baratheon       Balon/Euron Greyjoy        The North
# 30         Stannis Baratheon       Balon/Euron Greyjoy        The North
# 31       Balon/Euron Greyjoy  Joffrey/Tommen Baratheon        The Reach
# 32       Balon/Euron Greyjoy  Joffrey/Tommen Baratheon        The Reach
# 33  Joffrey/Tommen Baratheon         Stannis Baratheon   The Stormlands
# 34  Joffrey/Tommen Baratheon         Stannis Baratheon   The Stormlands
# 35  Joffrey/Tommen Baratheon                Robb Stark   The Riverlands
# 36  Joffrey/Tommen Baratheon                Robb Stark   The Riverlands
#
#    attacker_outcome
# 0               win
# 1               win
# 2               win
# 3              loss
# 4               win
# 5               win
# 6               win
# 7               win
# 8               win
# 9               win
# 10              win
# 11              win
# 12              win
# 13              win
# 14              win
# 15              win
# 16             loss
# 17              win
# 18              win
# 19             loss
# 20              win
# 21             loss
# 23              win
# 25              win
# 26              win
# 27             loss
# 28              win
# 30              win
# 31              win
# 32              win
# 33              win
# 34              win
# 35              win
# 36              win

# %%
def find_wins_of_attackers(df):
    attacker_wins = {}
    for king, outcome in zip(df.attacker_king, df.attacker_outcome):
        if not (king is np.nan or king != king) and not (outcome is np.nan or outcome != outcome):
            if outcome == "win":
                if king not in attacker_wins.keys():
                    attacker_wins[king] = 1
                else:
                    attacker_wins[king] += 1

    return attacker_wins

def find_wins_by_defenders(df):
    defender_wins = {}
    for king, outcome in zip(df.defender_king, df.attacker_outcome):
        if not (king is np.nan or king != king) and not (outcome is np.nan or outcome != outcome):
            if outcome == "loss":
                if king not in defender_wins.keys():
                    defender_wins[king] = 1
                else:
                    defender_wins[king] += 1
#         print(defender_wins)
    
    return defender_wins

def combine_wins(def_wins, attack_wins):
    combined_wins = {}
    for k, v in def_wins.items():
        if k not in combined_wins.keys():
            combined_wins[k] = v
        else:
            combined_wins[k] += v
            
    for k, v in attack_wins.items():
        if k not in combined_wins.keys():
            combined_wins[k] = v
        else:
            combined_wins[k] += v
    
    return combined_wins


attacker_wins = find_wins_of_attackers(df)
defender_wins = find_wins_by_defenders(df)
# print(defender_wins)
# print(attacker_wins)
combined_wins = combine_wins(defender_wins, attacker_wins)
wins_by_attacker = pd.DataFrame({'king': list(combined_wins.keys()), 'wins': list(combined_wins.values())})
wins_by_attacker
# Out:
#                        king  wins
# 0  Joffrey/Tommen Baratheon    16
# 1                Robb Stark     9
# 2              Mance Rayder     1
# 3       Balon/Euron Greyjoy     7
# 4         Stannis Baratheon     2

# %%
sns.barplot(x=wins_by_attacker.king, y=wins_by_attacker.wins)
plt.xticks(rotation=45)
# Out:
# (array([0, 1, 2, 3, 4]), <a list of 5 Text xticklabel objects>)
